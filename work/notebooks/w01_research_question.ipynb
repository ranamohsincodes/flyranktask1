# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ranamohsincodes/flyranktask1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I'm choosing this lane because I already explored this data in Weeks 1-2 and found a real signal: a hand-written rule scored 0.68-0.90 Precision@K, and a decision tree matched or beat it depending on depth. This tells me the "stale but still visible" pattern genuinely separates declining pages from stable ones — it isn't noise. Since FlyRank's clients constantly need to know which pages to refresh first, this connects directly to a real, recurring decision, and I already have a data foundation to build on.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Decision: which pages should a content team prioritize for review/refresh this week.
#
# Action: a content writer or SEO strategist picks pages from a ranked list and updates them (rewrite, add fresh info, fix outdated claims).
#
# Cost of a wrong call: if the model flags a page as "needs refresh" but it's actually fine, the team wastes writer hours that could've gone to a genuinely declining page. If it misses a real decliner, that page keeps losing visibility unnoticed — a slower, quieter cost, but a real one over weeks.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/ranamohsincodes/flyranktask1"
REPO_DIR = "flyranktask1"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
else:
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.columns.tolist())

# Build the "declining" label directly, since it isn't in the raw CSV
df["is_declining"] = (df["trend_direction"] == "down").astype(int)

print(f"Declining rate: {df['is_declining'].mean():.1%}")
print(f"Median days since last update (declining pages): {df[df['is_declining']==1]['days_since_last_update'].median():.0f}")
# Out:
# Working dir: /content/flyranktask1/flyranktask1/flyranktask1
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# Declining rate: 54.2%
# Median days since last update (declining pages): 20

# %% [markdown]
# Two numbers from the starter dataset that support this lane:

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# What I can say: this work is observed and directional — it flags pages whose traffic pattern statistically resembles past decliners, based on measurable signals (staleness, visibility, position).
#
# What I can't say: I cannot claim this proves why a page is declining, or that refreshing it will fix rankings. I'm not predicting Google's algorithm — I'm surfacing decision-support candidates for a human to review, not causal proof of anything.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
